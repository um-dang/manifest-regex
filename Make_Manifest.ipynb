# %%
# Python library to handle paths / filenames / listing directories
import os
# Python Regular Expression library
import re
# The Python data analysis library: https://pandas.pydata.org/
import pandas as pd

# %%
# Dummy read files are located in the subdirectory. These are empty, but for our manifest generation, that's fine!
BASEDIR = 'reads/'

# %%
# First let's grab the contents of our directory
filenames = os.listdir(BASEDIR)
filenames
# Out:
# ['CC11CM0_S1_L001_R1_001.fastq.gz',
#  'CC11CM0_S1_L001_R2_001.fastq.gz',
#  'CC11CM10_S11_L001_R1_001.fastq.gz',
#  'CC11CM10_S11_L001_R2_001.fastq.gz',
#  'CC11CM11_S12_L001_R1_001.fastq.gz',
#  'CC11CM11_S12_L001_R2_001.fastq.gz',
#  'CC11CM12_S13_L001_R1_001.fastq.gz',
#  'CC11CM12_S13_L001_R2_001.fastq.gz',
#  'CC11CM13_S14_L001_R1_001.fastq.gz',
#  'CC11CM13_S14_L001_R2_001.fastq.gz',
#  'CC11CM14_S15_L001_R1_001.fastq.gz',
#  'CC11CM14_S15_L001_R2_001.fastq.gz',
#  'CC11CM15_S16_L001_R1_001.fastq.gz',
#  'CC11CM15_S16_L001_R2_001.fastq.gz',
#  'CC11CM16_S17_L001_R1_001.fastq.gz',
#  'CC11CM16_S17_L001_R2_001.fastq.gz',
#  'CC11CM17_S18_L001_R1_001.fastq.gz',
#  'CC11CM17_S18_L001_R2_001.fastq.gz',
#  'CC11CM18_S19_L001_R1_001.fastq.gz',
#  'CC11CM18_S19_L001_R2_001.fastq.gz',
#  'CC11CM19_S20_L001_R1_001.fastq.gz',
#  'CC11CM19_S20_L001_R2_001.fastq.gz',
#  'CC11CM1_S2_L001_R1_001.fastq.gz',
#  'CC11CM1_S2_L001_R2_001.fastq.gz',
#  'CC11CM20_S21_L001_R1_001.fastq.gz',
#  'CC11CM20_S21_L001_R2_001.fastq.gz',
#  'CC11CM21_S22_L001_R1_001.fastq.gz',
#  'CC11CM21_S22_L001_R2_001.fastq.gz',
#  'CC11CM22_S23_L001_R1_001.fastq.gz',
#  'CC11CM22_S23_L001_R2_001.fastq.gz',
#  'CC11CM23_S24_L001_R1_001.fastq.gz',
#  'CC11CM23_S24_L001_R2_001.fastq.gz',
#  'CC11CM24_S25_L001_R1_001.fastq.gz',
#  'CC11CM24_S25_L001_R2_001.fastq.gz',
#  'CC11CM25_S26_L001_R1_001.fastq.gz',
#  'CC11CM25_S26_L001_R2_001.fastq.gz',
#  'CC11CM26_S27_L001_R1_001.fastq.gz',
#  'CC11CM26_S27_L001_R2_001.fastq.gz',
#  'CC11CM27_S28_L001_R1_001.fastq.gz',
#  'CC11CM27_S28_L001_R2_001.fastq.gz',
#  'CC11CM28_S29_L001_R1_001.fastq.gz',
#  'CC11CM28_S29_L001_R2_001.fastq.gz',
#  'CC11CM29_S30_L001_R1_001.fastq.gz',
#  'CC11CM29_S30_L001_R2_001.fastq.gz',
#  'CC11CM2_S3_L001_R1_001.fastq.gz',
#  'CC11CM2_S3_L001_R2_001.fastq.gz',
#  'CC11CM30_S31_L001_R1_001.fastq.gz',
#  'CC11CM30_S31_L001_R2_001.fastq.gz',
#  'CC11CM31_S32_L001_R1_001.fastq.gz',
#  'CC11CM31_S32_L001_R2_001.fastq.gz',
#  'CC11CM32_S33_L001_R1_001.fastq.gz',
#  'CC11CM32_S33_L001_R2_001.fastq.gz',
#  'CC11CM33_S34_L001_R1_001.fastq.gz',
#  'CC11CM33_S34_L001_R2_001.fastq.gz',
#  'CC11CM34_S35_L001_R1_001.fastq.gz',
#  'CC11CM34_S35_L001_R2_001.fastq.gz',
#  'CC11CM35_S36_L001_R1_001.fastq.gz',
#  'CC11CM35_S36_L001_R2_001.fastq.gz',
#  'CC11CM36_S37_L001_R1_001.fastq.gz',
#  'CC11CM36_S37_L001_R2_001.fastq.gz',
#  'CC11CM37_S38_L001_R1_001.fastq.gz',
#  'CC11CM37_S38_L001_R2_001.fastq.gz',
#  'CC11CM38_S39_L001_R1_001.fastq.gz',
#  'CC11CM38_S39_L001_R2_001.fastq.gz',
#  'CC11CM39_S40_L001_R1_001.fastq.gz',
#  'CC11CM39_S40_L001_R2_001.fastq.gz',
#  'CC11CM3_S4_L001_R1_001.fastq.gz',
#  'CC11CM3_S4_L001_R2_001.fastq.gz',
#  'CC11CM40_S41_L001_R1_001.fastq.gz',
#  'CC11CM40_S41_L001_R2_001.fastq.gz',
#  'CC11CM41_S42_L001_R1_001.fastq.gz',
#  'CC11CM41_S42_L001_R2_001.fastq.gz',
#  'CC11CM42_S43_L001_R1_001.fastq.gz',
#  'CC11CM42_S43_L001_R2_001.fastq.gz',
#  'CC11CM43_S44_L001_R1_001.fastq.gz',
#  'CC11CM43_S44_L001_R2_001.fastq.gz',
#  'CC11CM44_S45_L001_R1_001.fastq.gz',
#  'CC11CM44_S45_L001_R2_001.fastq.gz',
#  'CC11CM45_S46_L001_R1_001.fastq.gz',
#  'CC11CM45_S46_L001_R2_001.fastq.gz',
#  'CC11CM46_S47_L001_R1_001.fastq.gz',
#  'CC11CM46_S47_L001_R2_001.fastq.gz',
#  'CC11CM47_S48_L001_R1_001.fastq.gz',
#  'CC11CM47_S48_L001_R2_001.fastq.gz',
#  'CC11CM48_S49_L001_R1_001.fastq.gz',
#  'CC11CM48_S49_L001_R2_001.fastq.gz',
#  'CC11CM49_S50_L001_R1_001.fastq.gz',
#  'CC11CM49_S50_L001_R2_001.fastq.gz',
#  'CC11CM4_S5_L001_R1_001.fastq.gz',
#  'CC11CM4_S5_L001_R2_001.fastq.gz',
#  'CC11CM50_S51_L001_R1_001.fastq.gz',
#  'CC11CM50_S51_L001_R2_001.fastq.gz',
#  'CC11CM51_S52_L001_R1_001.fastq.gz',
#  'CC11CM51_S52_L001_R2_001.fastq.gz',
#  'CC11CM52_S53_L001_R1_001.fastq.gz',
#  'CC11CM52_S53_L001_R2_001.fastq.gz',
#  'CC11CM53_S54_L001_R1_001.fastq.gz',
#  'CC11CM53_S54_L001_R2_001.fastq.gz',
#  'CC11CM54_S55_L001_R1_001.fastq.gz',
#  'CC11CM54_S55_L001_R2_001.fastq.gz',
#  'CC11CM55_S56_L001_R1_001.fastq.gz',
#  'CC11CM55_S56_L001_R2_001.fastq.gz',
#  'CC11CM56_S57_L001_R1_001.fastq.gz',
#  'CC11CM56_S57_L001_R2_001.fastq.gz',
#  'CC11CM57_S58_L001_R1_001.fastq.gz',
#  'CC11CM57_S58_L001_R2_001.fastq.gz',
#  'CC11CM58_S59_L001_R1_001.fastq.gz',
#  'CC11CM58_S59_L001_R2_001.fastq.gz',
#  'CC11CM59_S60_L001_R1_001.fastq.gz',
#  'CC11CM59_S60_L001_R2_001.fastq.gz',
#  'CC11CM5_S6_L001_R1_001.fastq.gz',
#  'CC11CM5_S6_L001_R2_001.fastq.gz',
#  'CC11CM60_S61_L001_R1_001.fastq.gz',
#  'CC11CM60_S61_L001_R2_001.fastq.gz',
#  'CC11CM61_S62_L001_R1_001.fastq.gz',
#  'CC11CM61_S62_L001_R2_001.fastq.gz',
#  'CC11CM62_S63_L001_R1_001.fastq.gz',
#  'CC11CM62_S63_L001_R2_001.fastq.gz',
#  'CC11CM63_S64_L001_R1_001.fastq.gz',
#  'CC11CM63_S64_L001_R2_001.fastq.gz',
#  'CC11CM64_S65_L001_R1_001.fastq.gz',
#  'CC11CM64_S65_L001_R2_001.fastq.gz',
#  'CC11CM65_S66_L001_R1_001.fastq.gz',
#  'CC11CM65_S66_L001_R2_001.fastq.gz',
#  'CC11CM66_S67_L001_R1_001.fastq.gz',
#  'CC11CM66_S67_L001_R2_001.fastq.gz',
#  'CC11CM67_S68_L001_R1_001.fastq.gz',
#  'CC11CM67_S68_L001_R2_001.fastq.gz',
#  'CC11CM68_S69_L001_R1_001.fastq.gz',
#  'CC11CM68_S69_L001_R2_001.fastq.gz',
#  'CC11CM69_S70_L001_R1_001.fastq.gz',
#  'CC11CM69_S70_L001_R2_001.fastq.gz',
#  'CC11CM6_S7_L001_R1_001.fastq.gz',
#  'CC11CM6_S7_L001_R2_001.fastq.gz',
#  'CC11CM70_S71_L001_R1_001.fastq.gz',
#  'CC11CM70_S71_L001_R2_001.fastq.gz',
#  'CC11CM71_S72_L001_R1_001.fastq.gz',
#  'CC11CM71_S72_L001_R2_001.fastq.gz',
#  'CC11CM72_S73_L001_R1_001.fastq.gz',
#  'CC11CM72_S73_L001_R2_001.fastq.gz',
#  'CC11CM73_S74_L001_R1_001.fastq.gz',
#  'CC11CM73_S74_L001_R2_001.fastq.gz',
#  'CC11CM74_S75_L001_R1_001.fastq.gz',
#  'CC11CM74_S75_L001_R2_001.fastq.gz',
#  'CC11CM75_S76_L001_R1_001.fastq.gz',
#  'CC11CM75_S76_L001_R2_001.fastq.gz',
#  'CC11CM76_S77_L001_R1_001.fastq.gz',
#  'CC11CM76_S77_L001_R2_001.fastq.gz',
#  'CC11CM77_S78_L001_R1_001.fastq.gz',
#  'CC11CM77_S78_L001_R2_001.fastq.gz',
#  'CC11CM78_S79_L001_R1_001.fastq.gz',
#  'CC11CM78_S79_L001_R2_001.fastq.gz',
#  'CC11CM79_S80_L001_R1_001.fastq.gz',
#  'CC11CM79_S80_L001_R2_001.fastq.gz',
#  'CC11CM7_S8_L001_R1_001.fastq.gz',
#  'CC11CM7_S8_L001_R2_001.fastq.gz',
#  'CC11CM80_S81_L001_R1_001.fastq.gz',
#  'CC11CM80_S81_L001_R2_001.fastq.gz',
#  'CC11CM81_S82_L001_R1_001.fastq.gz',
#  'CC11CM81_S82_L001_R2_001.fastq.gz',
#  'CC11CM82_S83_L001_R1_001.fastq.gz',
#  'CC11CM82_S83_L001_R2_001.fastq.gz',
#  'CC11CM83_S84_L001_R1_001.fastq.gz',
#  'CC11CM83_S84_L001_R2_001.fastq.gz',
#  'CC11CM84_S85_L001_R1_001.fastq.gz',
#  'CC11CM84_S85_L001_R2_001.fastq.gz',
#  'CC11CM85_S86_L001_R1_001.fastq.gz',
#  'CC11CM85_S86_L001_R2_001.fastq.gz',
#  'CC11CM86_S87_L001_R1_001.fastq.gz',
#  'CC11CM86_S87_L001_R2_001.fastq.gz',
#  'CC11CM87_S88_L001_R1_001.fastq.gz',
#  'CC11CM87_S88_L001_R2_001.fastq.gz',
#  'CC11CM88_S89_L001_R1_001.fastq.gz',
#  'CC11CM88_S89_L001_R2_001.fastq.gz',
#  'CC11CM89_S90_L001_R1_001.fastq.gz',
#  'CC11CM89_S90_L001_R2_001.fastq.gz',
#  'CC11CM8_S9_L001_R1_001.fastq.gz',
#  'CC11CM8_S9_L001_R2_001.fastq.gz',
#  'CC11CM90_S91_L001_R1_001.fastq.gz',
#  'CC11CM90_S91_L001_R2_001.fastq.gz',
#  'CC11CM91_S92_L001_R1_001.fastq.gz',
#  'CC11CM91_S92_L001_R2_001.fastq.gz',
#  'CC11CM92_S93_L001_R1_001.fastq.gz',
#  'CC11CM92_S93_L001_R2_001.fastq.gz',
#  'CC11CM93_S94_L001_R1_001.fastq.gz',
#  'CC11CM93_S94_L001_R2_001.fastq.gz',
#  'CC11CM94_S95_L001_R1_001.fastq.gz',
#  'CC11CM94_S95_L001_R2_001.fastq.gz',
#  'CC11CM95_S96_L001_R1_001.fastq.gz',
#  'CC11CM95_S96_L001_R2_001.fastq.gz',
#  'CC11CM96_S97_L001_R1_001.fastq.gz',
#  'CC11CM96_S97_L001_R2_001.fastq.gz',
#  'CC11CM97_S98_L001_R1_001.fastq.gz',
#  'CC11CM97_S98_L001_R2_001.fastq.gz',
#  'CC11CM98_S99_L001_R1_001.fastq.gz',
#  'CC11CM98_S99_L001_R2_001.fastq.gz',
#  'CC11CM99_S100_L001_R1_001.fastq.gz',
#  'CC11CM99_S100_L001_R2_001.fastq.gz',
#  'CC11CM9_S10_L001_R1_001.fastq.gz',
#  'CC11CM9_S10_L001_R2_001.fastq.gz']

# %%
# Here is the regular expression we built over at https://pythex.org
re_fn = re.compile(r'^(?P<specimen>[A-Za-z0-9]+)_(S\d+)_(L\d+)_(?P<read>R\d)_(\d+)\.fastq\.gz$')

# %%
# Let's try it out, looking at the first filename
for filename in filenames:
    filename_match = re_fn.search(filename)
    break
filename_match
# Out:
# <re.Match object; span=(0, 31), match='CC11CM0_S1_L001_R1_001.fastq.gz'>

# %%
# The groupdict contains our *named* groups, in this case the specimen and read. 
filename_match.groupdict()
# Out:
# {'specimen': 'CC11CM0', 'read': 'R1'}

# %%
# We can also just access the named groups directly....
filename_match['specimen']
# Out:
# 'CC11CM0'

# %%
# We create an empty dataframe for our manifest...
manifest = pd.DataFrame()
for filename in filenames:
    # ... and then for each filename....
    filename_match = re_fn.search(filename)
    # ... use our regular expression to break the filename into parts
    if filename_match is None:
        # Check to be sure there are no filenames where our regular expression fails
        print(filename)
        continue
    # implicit else
    # ... set the specimen name
    manifest.loc[filename_match['specimen'], 'specimen'] = filename_match['specimen']
    # And the proper read (R1 or R2)
    manifest.loc[filename_match['specimen'], filename_match['read']] = os.path.join(BASEDIR, filename)
manifest
# Out:
#           specimen                                        R1  \
# CC11CM0    CC11CM0     reads/CC11CM0_S1_L001_R1_001.fastq.gz
# CC11CM10  CC11CM10   reads/CC11CM10_S11_L001_R1_001.fastq.gz
# CC11CM11  CC11CM11   reads/CC11CM11_S12_L001_R1_001.fastq.gz
# CC11CM12  CC11CM12   reads/CC11CM12_S13_L001_R1_001.fastq.gz
# CC11CM13  CC11CM13   reads/CC11CM13_S14_L001_R1_001.fastq.gz
# ...            ...                                       ...
# CC11CM96  CC11CM96   reads/CC11CM96_S97_L001_R1_001.fastq.gz
# CC11CM97  CC11CM97   reads/CC11CM97_S98_L001_R1_001.fastq.gz
# CC11CM98  CC11CM98   reads/CC11CM98_S99_L001_R1_001.fastq.gz
# CC11CM99  CC11CM99  reads/CC11CM99_S100_L001_R1_001.fastq.gz
# CC11CM9    CC11CM9    reads/CC11CM9_S10_L001_R1_001.fastq.gz
#
#                                                 R2
# CC11CM0      reads/CC11CM0_S1_L001_R2_001.fastq.gz
# CC11CM10   reads/CC11CM10_S11_L001_R2_001.fastq.gz
# CC11CM11   reads/CC11CM11_S12_L001_R2_001.fastq.gz
# CC11CM12   reads/CC11CM12_S13_L001_R2_001.fastq.gz
# CC11CM13   reads/CC11CM13_S14_L001_R2_001.fastq.gz
# ...                                            ...
# CC11CM96   reads/CC11CM96_S97_L001_R2_001.fastq.gz
# CC11CM97   reads/CC11CM97_S98_L001_R2_001.fastq.gz
# CC11CM98   reads/CC11CM98_S99_L001_R2_001.fastq.gz
# CC11CM99  reads/CC11CM99_S100_L001_R2_001.fastq.gz
# CC11CM9     reads/CC11CM9_S10_L001_R2_001.fastq.gz
#
# [100 rows x 3 columns]
